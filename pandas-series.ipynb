# %%
import pandas as pd

# %%
data = [2,4,6]
series = pd.Series(data,index= ['a','b','c'])
print(series)
# Out:
# a    2
# b    4
# c    6
# dtype: int64

# %%
data
# Out:
# [2, 4, 6]

# %%
print(series.loc['a'])#which element present at loction
# Out:
# 2

# %%
calories = {"day 1":1750, "day 2":1800, "day 3":1900}#dictionary

series = pd.Series(calories)
print(series.loc['day 1'])
print(series.loc['day 2'])
print(series[series > 1890])
# Out:
# 1750
# 1800
# day 3    1900
# dtype: int64
